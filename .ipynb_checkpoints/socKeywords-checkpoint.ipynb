# %%
import pandas as pd
from spacy.tokenizer import Tokenizer
import spacy
nlp = spacy.load('en_core_web_lg')
tokenizer = Tokenizer(nlp.vocab)
from spacy.lang.en.stop_words import STOP_WORDS
import numpy as np

# %%
df = pd.read_excel("./soc_2018_definitions.xlsx")

# %%
df = df.dropna()
df = df.reset_index()
df = df[['Unnamed: 2','Unnamed: 3']]
df.columns = ['title','desc']
df = df.drop(df.index[0])
# display(df)

# %%
import string
def removeStopwords(t):
    t = "".join(char for char in t if char not in string.punctuation)
    t = [token.orth_ for token in tokenizer(t) if token.orth_ not in STOP_WORDS and not token.is_punct and not token.is_space]
    return " ".join(char for char in t if char not in string.punctuation)

# %%
df['desc'] = df['desc'].apply(removeStopwords)
display(df)
# Out:
#                                                  title  \
# 1                                     Chief Executives
# 2                      General and Operations Managers
# 3                                          Legislators
# 4                  Advertising and Promotions Managers
# 5                                   Marketing Managers
# 6                                       Sales Managers
# 7                            Public Relations Managers
# 8                                 Fundraising Managers
# 9                     Administrative Services Managers
# 10                                 Facilities Managers
# 11           Computer and Information Systems Managers
# 12                                  Financial Managers
# 13                      Industrial Production Managers
# 14                                 Purchasing Managers
# 15   Transportation, Storage, and Distribution Mana...
# 16                  Compensation and Benefits Managers
# 17                            Human Resources Managers
# 18                   Training and Development Managers
# 19   Farmers, Ranchers, and Other Agricultural Mana...
# 20                               Construction Managers
# 21   Education and Childcare Administrators, Presch...
# 22   Education Administrators, Kindergarten through...
# 23             Education Administrators, Postsecondary
# 24                 Education Administrators, All Other
# 25              Architectural and Engineering Managers
# 26                               Food Service Managers
# 27                                   Gambling Managers
# 28   Entertainment and Recreation Managers, Except ...
# 29                                    Lodging Managers
# 30                Medical and Health Services Managers
# ..                                                 ...
# 838                 Cleaners of Vehicles and Equipment
# 839  Laborers and Freight, Stock, and Material Move...
# 840                     Machine Feeders and Offbearers
# 841                        Packers and Packagers, Hand
# 842                         Stockers and Order Fillers
# 843   Gas Compressor and Gas Pumping Station Operators
# 844            Pump Operators, Except Wellhead Pumpers
# 845                                   Wellhead Pumpers
# 846          Refuse and Recyclable Material Collectors
# 847                  Tank Car, Truck, and Ship Loaders
# 848                 Material Moving Workers, All Other
# 849                                  Air Crew Officers
# 850              Aircraft Launch and Recovery Officers
# 851                   Armored Assault Vehicle Officers
# 852                     Artillery and Missile Officers
# 853                Command and Control Center Officers
# 854                                  Infantry Officers
# 855                            Special Forces Officers
# 856  Military Officer Special and Tactical Operatio...
# 857         First-Line Supervisors of Air Crew Members
# 858  First-Line Supervisors of Weapons Specialists/...
# 859  First-Line Supervisors of All Other Tactical O...
# 860                                   Air Crew Members
# 861           Aircraft Launch and Recovery Specialists
# 862               Armored Assault Vehicle Crew Members
# 863                 Artillery and Missile Crew Members
# 864             Command and Control Center Specialists
# 865                                           Infantry
# 866                                     Special Forces
# 867  Military Enlisted Tactical Operations and Air/...
#
#                                                   desc
# 1    Determine formulate policies provide overall d...
# 2    Plan direct coordinate operations public priva...
# 3    Develop introduce enact laws statutes local tr...
# 4    Plan direct coordinate advertising policies pr...
# 5    Plan direct coordinate marketing policies prog...
# 6    Plan direct coordinate actual distribution mov...
# 7    Plan direct coordinate activities designed cre...
# 8    Plan direct coordinate activities solicit main...
# 9    Plan direct coordinate administrative services...
# 10   Plan direct coordinate operations functionalit...
# 11   Plan direct coordinate activities fields elect...
# 12   Plan direct coordinate accounting investing ba...
# 13   Plan direct coordinate work activities resourc...
# 14   Plan direct coordinate activities buyers purch...
# 15   Plan direct coordinate transportation storage ...
# 16   Plan direct coordinate compensation benefits a...
# 17   Plan direct coordinate human resources activit...
# 18   Plan direct coordinate training development ac...
# 19   Plan direct coordinate management operation fa...
# 20   Plan direct coordinate usually subordinate sup...
# 21   Plan direct coordinate academic nonacademic ac...
# 22   Plan direct coordinate academic administrative...
# 23   Plan direct coordinate student instruction adm...
# 24      All education administrators listed separately
# 25   Plan direct coordinate activities fields archi...
# 26   Plan direct coordinate activities organization...
# 27   Plan direct coordinate gambling operations cas...
# 28   Plan direct coordinate entertainment recreatio...
# 29   Plan direct coordinate activities organization...
# 30   Plan direct coordinate medical health services...
# ..                                                 ...
# 838  Wash clean vehicles machinery equipment Use ma...
# 839  Manually freight stock luggage materials perfo...
# 840  Feed materials remove materials machines equip...
# 841  Pack package hand wide variety products materials
# 842  Receive store issue merchandise materials equi...
# 843  Operate steam gas electric motor internal comb...
# 844  Tend control operate powerdriven stationary po...
# 845  Operate power pumps auxiliary equipment produc...
# 846  Collect dump refuse recyclable materials conta...
# 847  Load unload chemicals bulk solids coal sand gr...
# 848      All material moving workers listed separately
# 849  Perform direct inflight duties ensure successf...
# 850  Plan direct operation maintenance catapults ar...
# 851  Direct operation tanks light armor amphibious ...
# 852  Manage personnel weapons operations destroy en...
# 853  Manage operation communications detection weap...
# 854  Direct train lead infantry units ground combat...
# 855  Lead elite teams implement unconventional oper...
# 856  All military officer special tactical operatio...
# 857  Supervise coordinate activities air crew membe...
# 858  Supervise coordinate activities weapons specia...
# 859  Supervise coordinate activities tactical opera...
# 860  Perform inflight duties ensure successful comp...
# 861  Operate maintain catapults arresting gear asso...
# 862  Operate tanks light armor amphibious assault v...
# 863  Target fire maintain weapons destroy enemy pos...
# 864  Operate monitor communications detection weapo...
# 865  Operate weapons equipment ground combat operat...
# 866  Implement unconventional operations air land s...
# 867  All military enlisted tactical operations airw...
#
# [867 rows x 2 columns]

# %%
topic_keywords = df['desc'].values

# %%
topic_docs = list(nlp.pipe(topic_keywords,
  batch_size=10000,
  n_threads=3))

# %%
topic_vectors = np.array([doc.vector if doc.has_vector else spacy.vocab[0].vector for doc in topic_docs])

# %%
keywords = [
    'rectum'
]
keyword_docs = list(nlp.pipe(keywords,
  batch_size=10000,
  n_threads=3))
keyword_vectors = np.array([doc.vector
  if doc.has_vector else spacy.vocab[0].vector
  for doc in keyword_docs])
# print('Vector for keyword “%s”: ' % keywords[0])
# print(keyword_vectors[0])

# %%
from sklearn.metrics.pairwise import cosine_similarity
# use numpy and scikit-learn vectorized implementations for performance
simple_sim = cosine_similarity(keyword_vectors, topic_vectors)
topic_idx = np.argsort(-simple_sim,axis=1)
# print(simple_sim)

# %%
count = 0
for k, i in zip(keywords, topic_idx):
    vectors = simple_sim[count]
    for j in i[:10]:
        print('“%s” is about %s' %(k, topic_labels[j]))
        print(vectors[j])
    count=count+1
# Out:
# “rectum” is about Physicians, Pathologists
# 0.43247983
# “rectum” is about Neurologists
# 0.41829044
# “rectum” is about Podiatrists
# 0.39527082
# “rectum” is about Chiropractors
# 0.38823617
# “rectum” is about Surgical Assistants
# 0.38599175
# “rectum” is about Oral and Maxillofacial Surgeons
# 0.38262188
# “rectum” is about Prosthodontists
# 0.37916082
# “rectum” is about Dermatologists
# 0.35755268
# “rectum” is about Anesthesiologists
# 0.35273898
# “rectum” is about Cardiologists
# 0.3516475
